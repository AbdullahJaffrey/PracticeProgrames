# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby('Sex')['Survived'].agg('count')
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
df2 = df.groupby(['Sex','Survived'])['Survived'].agg('count')

# %%
df2.head()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
df2.unstack(0)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
df[(df['Pclass'] == 3) & (df['Age']> 23)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 8              9         1       3
# 13            14         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 873          874         0       3
# 881          882         0       3
# 884          885         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'].str.startswith('J').sum()
# Out:
# 30

# %%
df[df['Name'].str.startswith('J')]
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 70            71         0       2
# 103          104         0       3
# 113          114         0       3
# 172          173         1       3
# 202          203         0       3
# 217          218         0       2
# 302          303         0       3
# 368          369         1       3
# 391          392         1       3
# 395          396         0       3
# 402          403         0       3
# 444          445         1       3
# 455          456         1       3
# 473          474         1       2
# 569          570         1       3
# 579          580         1       3
# 586          587         0       2
# 597          598         0       3
# 600          601         1       2
# 611          612         0       3
# 640          641         0       3
# 719          720         0       3
# 721          722         0       3
# 753          754         0       3
# ...

# %%
data2 = df[(df['Pclass'] == 3)  & (df['Name'].str.startswith('J')) & (df['Sex'] == 'male' )]

# %%
data2
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 103          104         0       3         Johansson, Mr. Gustaf Joel  male
# 202          203         0       3         Johanson, Mr. Jakob Alfred  male
# 302          303         0       3    Johnson, Mr. William Cahoone Jr  male
# 391          392         1       3             Jansson, Mr. Carl Olof  male
# 395          396         0       3                Johansson, Mr. Erik  male
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt  male
# 455          456         1       3                 Jalsevac, Mr. Ivan  male
# 569          570         1       3                  Jonsson, Mr. Carl  male
# 579          580         1       3                Jussila, Mr. Eiriik  male
# 597          598         0       3                Johnson, Mr. Alfred  male
# 611          612         0       3              Jardin, Mr. Jose Neto  male
# ...

# %%
df[(df['Pclass'] == 3)  & (df['Name'].str.startswith('J')) & (df['Sex'] == 'male' )].sum()
# Out:
# PassengerId                                                10728
# Survived                                                       6
# Pclass                                                        57
# Name           Johansson, Mr. Gustaf JoelJohanson, Mr. Jakob ...
# Sex            malemalemalemalemalemalemalemalemalemalemalema...
# Age                                                        447.0
# SibSp                                                          3
# Parch                                                          3
# Ticket         75403101264LINE35003435005265306349240350417ST...
# Fare                                                    150.3708
# Cabin                                                          0
# Embarked                                     SSSSSSCSSSSSSSSSSSS
# dtype: object

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
index_age = np.arange((df['Pclass'].count()))

# %%
df['Age'].shape
# Out:
# (891,)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df3 = df[df['Name'].str.endswith('k')]

# %%
df3.head()
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 59            60         0       3  Goodwin, Master. William Frederick  male
# 93            94         0       3             Dean, Mr. Bertram Frank  male
# 116          117         0       3                Connors, Mr. Patrick  male
# 201          202         0       3                 Sage, Mr. Frederick  male
# 267          268         1       3            Persson, Mr. Ernst Ulrik  male
#
#       Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 59   11.0      5      2    CA 2144  46.900   NaN        S
# 93   26.0      1      2  C.A. 2315  20.575   NaN        S
# 116  70.5      0      0     370369   7.750   NaN        Q
# 201   NaN      8      2   CA. 2343  69.550   NaN        S
# 267  25.0      1      0     347083   7.775   NaN        S

# %%
df3.plot()
# Out:
# <AxesSubplot:>

# %%
#Done
