# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.add_prefix('Passenger_')

# rename columns like this by adding 'Passenger' at start
# Out:
#      Passenger_PassengerId  Passenger_Survived  Passenger_Pclass  \
# 0                        1                   0                 3
# 1                        2                   1                 1
# 2                        3                   1                 3
# 3                        4                   1                 1
# 4                        5                   0                 3
# ..                     ...                 ...               ...
# 886                    887                   0                 2
# 887                    888                   1                 1
# 888                    889                   0                 3
# 889                    890                   1                 1
# 890                    891                   0                 3
#
#                                         Passenger_Name Passenger_Sex  \
# 0                              Braund, Mr. Owen Harris          male
# ...

# %%
new_df = df[df['Pclass'] == 3][['Name','Age']]
new_df.head(5)
# Out:
#                              Name   Age
# 0         Braund, Mr. Owen Harris  22.0
# 2          Heikkinen, Miss. Laina  26.0
# 4        Allen, Mr. William Henry  35.0
# 5                Moran, Mr. James   NaN
# 7  Palsson, Master. Gosta Leonard   2.0

# %%
new_df[new_df['Name'].str.startswith('Ab')]
# Out:
#                                  Name   Age
# 279  Abbott, Mrs. Stanton (Rosa Hunt)  35.0
# 746       Abbott, Mr. Rossmore Edward  16.0
# 845               Abbing, Mr. Anthony  42.0

# %%
new_df[new_df['Name'].str.startswith('Ab') | new_df['Name'].str.endswith('h') ]
# Out:
#                                   Name   Age
# 79            Dowdell, Miss. Elizabeth  30.0
# 95         Shorney, Mr. Charles Joseph   NaN
# 143                Burke, Mr. Jeremiah  19.0
# 279   Abbott, Mrs. Stanton (Rosa Hunt)  35.0
# 454                Peduzzi, Mr. Joseph   NaN
# 542  Andersson, Miss. Sigrid Elisabeth  11.0
# 589                Murdlin, Mr. Joseph   NaN
# 642      Skoog, Miss. Margit Elizabeth   2.0
# 727           Mannion, Miss. Margareth   NaN
# 746        Abbott, Mr. Rossmore Edward  16.0
# 752   Vande Velde, Mr. Johannes Joseph  33.0
# 787          Rice, Master. George Hugh   8.0
# 828       McCormack, Mr. Thomas Joseph   NaN
# 845                Abbing, Mr. Anthony  42.0

# %%
new_df[new_df['Name'].str.startswith('Ab') & new_df['Name'].str.endswith('h') ]
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
new_df[new_df['Name'].str.startswith('Ab') & new_df['Name'].str.endswith('y')]
# Out:
#                     Name   Age
# 845  Abbing, Mr. Anthony  42.0

# %%
new_df['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
new_df['Age'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
new_df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
new_df.isnull().sum()
# Out:
# Name      0
# Age     136
# dtype: int64

# %%
new_df.notnull().sum()
# Out:
# Name    491
# Age     355
# dtype: int64

# %%
new_df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
pd.DataFrame(new_df['Age'].describe())
# Out:
#               Age
# count  355.000000
# mean    25.140620
# std     12.495398
# min      0.420000
# 25%     18.000000
# 50%     24.000000
# 75%     32.000000
# max     74.000000

# %%
new_df[new_df['Age']>30]
# Out:
#                                                   Name   Age
# 4                             Allen, Mr. William Henry  35.0
# 13                         Andersson, Mr. Anders Johan  39.0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0
# ..                                                 ...   ...
# 860                            Hansen, Mr. Claus Peter  41.0
# 873                        Vander Cruyssen, Mr. Victor  47.0
# 881                                 Markun, Mr. Johann  33.0
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [103 rows x 2 columns]

# %%
new_df[new_df['Name'].str.split(',') == 'Allen']
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
new_df[new_df['Name'].str.startswith('Arnold')]
# Out:
#                                               Name   Age
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  18.0
# 353                      Arnold-Franchi, Mr. Josef  25.0

# %%
df[(df['Age'] >= 35) & ((df['Name'].str.startswith('R') | df['Name'].str.endswith('d')))]
# Out:
#      PassengerId  Survived  Pclass  \
# 108          109         0       3
# 124          125         0       1
# 132          133         0       3
# 160          161         0       3
# 187          188         1       1
# 224          225         1       1
# 245          246         0       1
# 248          249         1       1
# 254          255         0       3
# 265          266         0       2
# 332          333         0       1
# 397          398         0       2
# 434          435         0       1
# 482          483         0       3
# 492          493         0       1
# 513          514         1       1
# 526          527         1       2
# 544          545         0       1
# 583          584         0       1
# 590          591         0       3
# 597          598         0       3
# 614          615         0       3
# 626          627         0       2
# 661          662         0       3
# 698          699         0       1
# ...

# %%
df[(df['Age'] > 35) & (df['Age'] < 50) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 13            14         0       3
# 25            26         1       3
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
 df[(df['Name'].str.startswith('R') & df['Name'].str.endswith('d'))]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 265          266         0       2            Reeves, Mr. David  male  36.0
# 424          425         0       3  Rosblom, Mr. Viktor Richard  male  18.0
# 538          539         0       3     Risien, Mr. Samuel Beard  male   NaN
# 859          860         0       3             Razi, Mr. Raihed  male   NaN
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked
# 265      0      0  C.A. 17248  10.5000   NaN        S
# 424      1      1      370129  20.2125   NaN        S
# 538      0      0      364498  14.5000   NaN        S
# 859      0      0        2629   7.2292   NaN        C

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 122          123         0       2             Nasser, Mr. Nicholas    male
# 86            87         0       3           Ford, Mr. William Neal    male
# 337          338         1       1  Burns, Miss. Elizabeth Margaret  female
# 388          389         0       3             Sadlier, Mr. Matthew    male
# 96            97         0       1        Goldschmidt, Mr. George B    male
# 538          539         0       3         Risien, Mr. Samuel Beard    male
# 841          842         0       2         Mudd, Mr. Thomas Charles    male
# 624          625         0       3      Bowen, Mr. David John "Dai"    male
# 358          359         1       3             McGovern, Miss. Mary  female
# 22            23         1       3      McGowan, Miss. Anna "Annie"  female
#
#       Age  SibSp  Parch       Ticket      Fare Cabin Embarked
# 122  32.5      1      0       237736   30.0708   NaN        C
# ...

# %%
nation = ['British','American','French','Pakistani']

# %%
df['Nationality'] = np.random.choice(nation,891)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Nationality
# 0      0         A/5 21171   7.2500   NaN        S    American
# 1      0          PC 17599  71.2833   C85        C     British
# 2      0  STON/O2. 3101282   7.9250   NaN        S   Pakistani
# ...

# %%
df[df['Nationality']=='Pakistani']
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 6              7         0       1
# 15            16         1       2
# 20            21         0       2
# ..           ...       ...     ...
# 865          866         1       2
# 867          868         0       1
# 875          876         1       3
# 878          879         0       3
# 884          885         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# ...

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# Nationality    891
# dtype: int64

# %%
# Done
